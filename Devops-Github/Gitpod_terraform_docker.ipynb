# %% [markdown]
# # Create or confirm .gitpod.Dockerfile in your repo root:

# %%
import os
import time

# Mounting the GDrive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
#  Set your repo path:

# %%
repo_path = "/content/drive/MyDrive/Devops/Devops-Github"

# %% [markdown]
# Now create .gitpod.yml and .gitpod.Dockerfile:

# %%
import os

os.makedirs(repo_path, exist_ok=True)

# .gitpod.yml

with open(os.path.join(repo_path, ".gitpod.yml"), "w") as f:
    f.write('''# .gitpod.yml
# \\@prebuild

image:
  file: .gitpod.Dockerfile

tasks:
  - name: Setup Workspace
    init: |
      echo "✅ Workspace ready for Terraform + Docker"
''')

# .gitpod.Dockerfile

with open(os.path.join(repo_path, ".gitpod.Dockerfile"), "w") as f:
  f.write('''FROM gitpod/workspace-full

USER root

# Install Docker
RUN apt-get update && apt-get install -y docker.io

# Install Terraform (official script)
RUN curl -fsSL https://apt.releases.hashicorp.com/gpg | gpg --dearmor -o /usr/share/keyrings/hashicorp-archive-keyring.gpg && \
    echo "deb [signed-by=/usr/share/keyrings/hashicorp-archive-keyring.gpg] https://apt.releases.hashicorp.com bookworm main" | tee /etc/apt/sources.list.d/hashicorp.list && \
    apt-get update && apt-get install terraform -y

''')

print("✅ Gitpod config files created successfully.")
# Out:
# ✅ Gitpod config files created successfully.

# %%
# !git commit -m "Add Gitpod setup for Terraform + Docker"
# Out:
# [main f5f5c32] Add Gitpod setup for Terraform + Docker
#  5 files changed, 14 insertions(+), 1 deletion(-)
#  create mode 100644 Devops-Github/.gitpod.Dockerfile
#  create mode 100644 Devops-Github/.gitpod.yml
#  create mode 100644 Devops-Github/Gitpod_terraform_docker.ipynb
#  rewrite Week-1/Python_Logic_Arjun.ipynb (96%)

# %%
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path="/content/drive/MyDrive/Devops/.env")

token = os.getenv("GITHUB_TOKEN")
print("Loaded token:", token[:6] + "..." + token[-4:])  # Just to verify
# Out:
# Loaded token: ghp_Uc...f2wW

# %%
github_username = "nightwalker9999"
# !git push https://{github_username}:{token}@github.com/{github_username}/Devops-Github.git main
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 875 bytes | 72.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/nightwalker9999/Devops-Github.git
#    313c5c4..c54c6b1  main -> main

# %%
# !git add .
# !git commit -m "Fix: add @prebuild annotation for Gitpod rebuild"
# Out:
# [main c54c6b1] Fix: add @prebuild annotation for Gitpod rebuild
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Devops-Github/Gitpod_terraform_docker.ipynb (72%)

# %%
# !ls Devops-Github/
# Out:
# Gitpod_terraform_docker.ipynb
